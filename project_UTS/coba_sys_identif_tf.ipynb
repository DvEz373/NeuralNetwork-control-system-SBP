# %%
# !pip install numpy matplotlib scipy pandas seaborn plotly scikit-learn statsmodels tensorflow keras
# Out:
# Collecting numpy
#   Using cached numpy-2.1.3-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting matplotlib
#   Using cached matplotlib-3.9.2-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting scipy
#   Using cached scipy-1.14.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting pandas
#   Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting plotly
#   Using cached plotly-5.24.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting scikit-learn
#   Using cached scikit_learn-1.5.2-cp312-cp312-win_amd64.whl.metadata (13 kB)
# Collecting statsmodels
#   Downloading statsmodels-0.14.4-cp312-cp312-win_amd64.whl.metadata (9.5 kB)
# Requirement already satisfied: tensorflow in c:\users\acer\appdata\roaming\python\python312\site-packages (2.17.0)
# Requirement already satisfied: keras in c:\users\acer\appdata\roaming\python\python312\site-packages (3.6.0)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.0-cp312-cp312-win_amd64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached fonttools-4.54.1-cp312-cp312-win_amd64.whl.metadata (167 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.4.7-cp312-cp312-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\acer\documents\python\sbp\project_uts\.conda\lib\site-packages (from matplotlib) (24.1)
# Collecting pillow>=8 (from matplotlib)
#   Using cached pillow-11.0.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Using cached pyparsing-3.2.0-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\acer\documents\python\sbp\project_uts\.conda\lib\site-packages (from matplotlib) (2.9.0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting tenacity>=6.2.0 (from plotly)
#   Downloading tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Collecting patsy>=0.5.6 (from statsmodels)
#   Using cached patsy-0.5.6-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: tensorflow-intel==2.17.0 in c:\users\acer\appdata\roaming\python\python312\site-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\acer\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\acer\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\acer\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\acer\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\acer\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.2.0)
# Collecting h5py>=3.10.0 (from tensorflow-intel==2.17.0->tensorflow)
#   Using cached h5py-3.12.1-cp312-cp312-win_amd64.whl.metadata (2.5 kB)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\acer\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in c:\users\acer\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\acer\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.4.0)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow-intel==2.17.0->tensorflow)
#   Using cached protobuf-4.25.5-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Collecting requests<3,>=2.21.0 (from tensorflow-intel==2.17.0->tensorflow)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: setuptools in c:\users\acer\documents\python\sbp\project_uts\.conda\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\acer\documents\python\sbp\project_uts\.conda\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\acer\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\acer\documents\python\sbp\project_uts\.conda\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (4.12.2)
# Collecting wrapt>=1.11.0 (from tensorflow-intel==2.17.0->tensorflow)
#   Using cached wrapt-1.16.0-cp312-cp312-win_amd64.whl.metadata (6.8 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow-intel==2.17.0->tensorflow)
#   Using cached grpcio-1.67.1-cp312-cp312-win_amd64.whl.metadata (4.0 kB)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in c:\users\acer\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.17.1)
# Collecting numpy
#   Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
# Collecting rich (from keras)
#   Using cached rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: namex in c:\users\acer\appdata\roaming\python\python312\site-packages (from keras) (0.0.8)
# Requirement already satisfied: optree in c:\users\acer\appdata\roaming\python\python312\site-packages (from keras) (0.13.0)
# Collecting markdown-it-py>=2.2.0 (from rich->keras)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\acer\documents\python\sbp\project_uts\.conda\lib\site-packages (from rich->keras) (2.18.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\acer\documents\python\sbp\project_uts\.conda\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.17.0->tensorflow) (0.44.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow)
#   Using cached charset_normalizer-3.4.0-cp312-cp312-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow)
#   Using cached urllib3-2.2.3-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow)
#   Using cached certifi-2024.8.30-py3-none-any.whl.metadata (2.2 kB)
# Collecting markdown>=2.6.8 (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow)
#   Using cached Markdown-3.7-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\acer\appdata\roaming\python\python312\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (0.7.2)
# Collecting werkzeug>=1.0.1 (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow)
#   Using cached werkzeug-3.1.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting MarkupSafe>=2.1.1 (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow)
#   Using cached MarkupSafe-3.0.2-cp312-cp312-win_amd64.whl.metadata (4.1 kB)
# Using cached matplotlib-3.9.2-cp312-cp312-win_amd64.whl (7.8 MB)
# Using cached scipy-1.14.1-cp312-cp312-win_amd64.whl (44.5 MB)
# Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading plotly-5.24.1-py3-none-any.whl (19.1 MB)
#    ---------------------------------------- 0.0/19.1 MB ? eta -:--:--
#    ---- ----------------------------------- 2.1/19.1 MB 11.7 MB/s eta 0:00:02
#    --------- ------------------------------ 4.7/19.1 MB 11.9 MB/s eta 0:00:02
#    -------------- ------------------------- 7.1/19.1 MB 11.8 MB/s eta 0:00:02
#    -------------------- ------------------- 9.7/19.1 MB 11.8 MB/s eta 0:00:01
#    ------------------------- -------------- 12.1/19.1 MB 11.8 MB/s eta 0:00:01
#    ------------------------------ --------- 14.4/19.1 MB 11.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 17.0/19.1 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------- 19.1/19.1 MB 11.5 MB/s eta 0:00:00
# Using cached scikit_learn-1.5.2-cp312-cp312-win_amd64.whl (11.0 MB)
# Downloading statsmodels-0.14.4-cp312-cp312-win_amd64.whl (9.8 MB)
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    -------- ------------------------------- 2.1/9.8 MB 13.0 MB/s eta 0:00:01
#    ----------------- ---------------------- 4.2/9.8 MB 10.1 MB/s eta 0:00:01
#    --------------------------- ------------ 6.8/9.8 MB 10.7 MB/s eta 0:00:01
#    -------------------------------------- - 9.4/9.8 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 10.4 MB/s eta 0:00:00
# Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl (15.5 MB)
# Using cached contourpy-1.3.0-cp312-cp312-win_amd64.whl (218 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.54.1-cp312-cp312-win_amd64.whl (2.2 MB)
# Using cached h5py-3.12.1-cp312-cp312-win_amd64.whl (3.0 MB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Using cached kiwisolver-1.4.7-cp312-cp312-win_amd64.whl (55 kB)
# Using cached patsy-0.5.6-py2.py3-none-any.whl (233 kB)
# Using cached pillow-11.0.0-cp312-cp312-win_amd64.whl (2.6 MB)
# Using cached pyparsing-3.2.0-py3-none-any.whl (106 kB)
# Using cached pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Downloading tenacity-9.0.0-py3-none-any.whl (28 kB)
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Using cached tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# Using cached rich-13.9.4-py3-none-any.whl (242 kB)
# Using cached grpcio-1.67.1-cp312-cp312-win_amd64.whl (4.3 MB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached protobuf-4.25.5-cp310-abi3-win_amd64.whl (413 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached wrapt-1.16.0-cp312-cp312-win_amd64.whl (37 kB)
# Using cached certifi-2024.8.30-py3-none-any.whl (167 kB)
# Using cached charset_normalizer-3.4.0-cp312-cp312-win_amd64.whl (102 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached Markdown-3.7-py3-none-any.whl (106 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached urllib3-2.2.3-py3-none-any.whl (126 kB)
# Using cached werkzeug-3.1.2-py3-none-any.whl (224 kB)
# Using cached MarkupSafe-3.0.2-cp312-cp312-win_amd64.whl (15 kB)
# Installing collected packages: pytz, wrapt, urllib3, tzdata, threadpoolctl, tenacity, pyparsing, protobuf, pillow, numpy, mdurl, MarkupSafe, markdown, kiwisolver, joblib, idna, grpcio, fonttools, cycler, charset-normalizer, certifi, werkzeug, scipy, requests, plotly, patsy, pandas, markdown-it-py, h5py, contourpy, statsmodels, scikit-learn, rich, matplotlib, seaborn
# Successfully installed MarkupSafe-3.0.2 certifi-2024.8.30 charset-normalizer-3.4.0 contourpy-1.3.0 cycler-0.12.1 fonttools-4.54.1 grpcio-1.67.1 h5py-3.12.1 idna-3.10 joblib-1.4.2 kiwisolver-1.4.7 markdown-3.7 markdown-it-py-3.0.0 matplotlib-3.9.2 mdurl-0.1.2 numpy-1.26.4 pandas-2.2.3 patsy-0.5.6 pillow-11.0.0 plotly-5.24.1 protobuf-4.25.5 pyparsing-3.2.0 pytz-2024.2 requests-2.32.3 rich-13.9.4 scikit-learn-1.5.2 scipy-1.14.1 seaborn-0.13.2 statsmodels-0.14.4 tenacity-9.0.0 threadpoolctl-3.5.0 tzdata-2024.2 urllib3-2.2.3 werkzeug-3.1.2 wrapt-1.16.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# huggingface-hub 0.25.1 requires filelock, which is not installed.
# huggingface-hub 0.25.1 requires fsspec>=2023.5.0, which is not installed.
# huggingface-hub 0.25.1 requires pyyaml>=5.1, which is not installed.
# huggingface-hub 0.25.1 requires tqdm>=4.42.1, which is not installed.
# ultralytics-thop 2.0.9 requires torch, which is not installed.

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from scipy import signal
import tensorflow as tf
